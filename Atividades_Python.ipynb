# %% [markdown]
# # Atividades feitas em Python no curso de Lógica de programação da faculdade UNIFESP

# %%
"""
Created on Thu Jul 22 23:48:05 2021

@author: Stevie - 141032 - noturno
"""

def qt_vogais(txt):
    vogais = ["A", "E", "I", "O", "U"]
    qt_vogais = 0
    for letras in txt:
        if letras in vogais:
            qt_vogais += 1
    return qt_vogais if qt_vogais > 0 else -1

# %%
"""
Created on Mon May 17 19:10:08 2021

@author: Stevie Amorim -  141032
"""
#Um usuário necessita de um programa onde possa escolher que tipo de média 
#deseja calcular a partir de 3 notas. Faça um algoritmo que leia as notas, a 
#opção escolhida pelo usuário e calcule a média.
#1 -aritmética
#2 -ponderada (pesos = 3,3,4)

n1 = float(input('Primeira nota: '))
n2 = float(input('Segunda nota: '))
n3 = float(input('Terceira nota: '))
escolha = int(input("Qual média você deseja? 1) Aritmética ou 2)Ponderada:   "))
if escolha == 1:
    resultadoAr = (n1+n2+n3)/3
    print("A média da nota é: ", resultadoAr)
if escolha == 2:
    resultado = ((n1*3) + (n2*3) + (n3*4)) / 10
    print("A média da nota é: ", resultado)
if escolha >2 and escolha <0:
    print("Opção inválida!!! Refaça novamente!")

# %%
"""
Created on Thu Aug 09 21:11:18 2021

@author: Stevie Ferreira Amorim - 141032
Armazenando somente número par.
"""
#Ex2.
def return_par_impar(lista):
    cont =0
    contIp = 0
    for x in lista:
        if x % 2 == 0:
            cont += 1
        else:
            contIp += 1
    return (cont, contIp)

# %%
"""
Created on Thu Aug 09 20:48:01 2021

@author: Stevie Ferreira Amorim - 141032

Número de medalhas, utilizando listas dentro de arrays e funções.
"""

qd_medalhas = {'China':[1, 2, 3], 'usa':[2,2,1], 'Brasil':[20, 30, 40], 'Japão':[0,2,3], 'Australia':[5, 3, 2]}

def verif_Medalhas(país):
    if país in qd_medalhas:
        ouro = qd_medalhas[país][0]
        bronze = qd_medalhas[país][2]
        prata = qd_medalhas[país][1]
        total = qd_medalhas[país]
        
        print('O ', país, 'está com:', ouro, 'medalhas de ouro', prata, 'medalhas de prata ', bronze, 'medalhas de bronze.')
        return total
    else:
        print('País não existe.')
        
def insert_Pais(país, qt_ouro, qt_prata, qt_bronze):
    if país in qd_medalhas:
        print('O país já cadastrado')
        
    else:
        qd_medalhas[país]=[qt_ouro, qt_prata, qt_bronze]
        insert_Pais('Bolivia', 1, 2, 3)
        
def atualizacao_Medalhas(pais,tp_medalha,qtde):
    tp_medalha = tp_medalha.lower()
    if pais in qd_medalhas:
        if tp_medalha == 'bronze':
            x = 2
        if tp_medalha == 'prata':
            x = 1
        if tp_medalha == 'ouro':
            x = 0
        qd_medalhas['Brasil'][x] = qd_medalhas['Brasil'][x] + qtde
    else:
        print('País não existe..')
        
def lt_quadro():
    print( 'xXQuadro de medalhasXx')
    for x in qd_medalhas:
        pais = x
        ouro = qd_medalhas[x][0]
        prata = qd_medalhas[x][1]
        bronze = qd_medalhas[x][2]
        total = ouro + prata + bronze
        print(pais,'-', ouro, 'ouro -', prata, 'prata -', bronze, 'bronze -   total de :', total)
def maior_Qtd(tp_medalha):
    
    tp_medalha = tp_medalha.lower()
    maior = 0
    if tp_medalha == 'bronze':
        y = 2
    if tp_medalha == 'prata':
        y = 1
    if tp_medalha == 'ouro':
        y = 0
    for x in qd_medalhas:
        medalha = qd_medalhas[x][y]
        if medalha > maior:
            maior = medalha
            pais = x
            
    print(pais, maior)

# %%
"""
Created on Thu Jul 22 23:46:07 2021

@author: Stevie - 141032 - noturno
trocar o dia por Mês 
"""

def verificaPrimo(data):
          dd_data=(int(data[0])*10)
          du=(int(data[1]))
          de=dd_data+du
          md=(int(data[3])*10)
          mu=(int(data[4]))
          mes=md+mu
          am=(int(data[6])*1000)
          ac=(int(data[7])*100)
          ad=(int(data[8])*10)
          au=(int(data[9]))
          ano=am+ac+ad+au
          
          if mes == 1:
              print (de,"de Janeiro de",ano)
          if mes == 2:
              print (de,"de Fevereiro de",ano)
          if mes == 3:
              print (de,"de Março de",ano)
          if mes == 4:
              print (de,"de Abril de",ano)
          if mes == 5:
              print (de,"de Maio de",ano)
          if mes == 6:
              print (de,"de Junho de",ano)
          if mes == 7:
              print (de,"de Julho de",ano)
          if mes == 8:
              print (de,"de Agosto de",ano)
          if mes == 9:
              print (de,"de Setembro de",ano)
          if mes == 10:
              print (de,"de Outubro de",ano)
          if mes == 11:
              print (de,"de Novembro de",ano)
          if mes == 12:
              print (de,"de Dezembro de",ano)  
        
data=(input(str("Digite a data dd/mm/aaaa: ")))
verificaPrimo(data)
# Out:
# Digite a data dd/mm/aaaa: 16/06/2022
# 16 de Junho de 2022

# %%
"""
Created on Mon May 17 20:32:09 2021

@author:  Stevie Amorim -  141032
"""

#Um vendedor necessita de um programa que calcule o preço total devido por 
#um cliente. O programa deve receber o código de um produto e a quantidade 
#comprada e calcular o preço total, usando a tabela abaixo. Caso o código do 
#produto digitado seja diferente da tabela abaixo, imprimir a mensagem: Código 
#de produto inválido!
#Código do Produto Preço unitário
#1001 5,32
#1324 6,45
#2548 2,37
#4987 5,32
#7623 6,45
#A submissão deverá ser feita na forma de programas em Python.
#Cada exercício deverá ser colocado num arquivo Python (ex. exec1.py, exec2.py, 
#exec3.py) No início do arquivo, coloque seu RA e nome completo (ex. # 123456 
#Ada Lovelace)

valor = int(input("Digite o código primeiro: "))
if valor == 1001:
    cont = float(input("Digite a quantidade, por gentileza: "))
    result = cont * 5.32
    print("O preço total é: ", result)
if valor == 1324:
    cont = float(input("Digite a quantidade, por gentileza: "))
    result = cont * 6.45
    print("O preço total é: ", result)
if valor == 2548:
    cont = float(input("Digite a quantidade, por gentileza: "))
    result = cont * 2.37
    print("O preço total é: ", result)
if valor == 4987:
    cont = float(input("Digite a quantidade, por gentileza: "))
    result = cont * 5.32
    print("O preço total é: ", result)
if valor == 7623:
    cont = float(input("Digite a quantidade, por gentileza: "))
    result = cont * 6.45
    print("O preço total é: ", result)
if valor != 1001 and valor != 1324 and valor != 2548 and valor != 4987 and valor !=7623:
    print("Código inválido, tente outra vez!")

# %%
"""
Spyder Stevie

This is a temporary script file.
"""

"""
Determinar maior valor de dois números com if(fácil hehehe)
"""

a = int(input("Digite um número: "))
b= int(input("Digite o segundo número: "))

if a>b:
        print("O primeiro número é maior. Que é: ", a)
if a<b:
    print("o segundo número é o maior. Que é: ", b)
if a==b:
    print("Os números são iguais.")
else:
     print("Eu acho que você digitou errado, seu jumento!!!")

# %%
"""
Spyder Stevie

This is a temporary script file.
"""

"""
determinar o maior valor de dois números com seleção
"""

a = int(input("Digite um número: "))
b= int(input("Digite o segundo número: "))

if a>b:
    print("O primeiro número é maior. Que é: ", a)
#Comando elif = "senão se"
elif a<b:
    print("o segundo número é o maior. Que é: ", b)
else:
       print("Os números são iguais.")

# %%
"""
Spyder Stevie

This is a temporary script file.
"""

"""
São dados um número N e dois outros a e b, correspondentes, respectivamente, 
às extremidades do intervalo [a,b] e sendo a<b. Determinar se N pertence ao 
intervalo [a,b] ou se N não pertence a esse intervalo.
"""

a = 10
b = 20
n1 = int(input("Digite um número: "))

if n1>= a and n1<=b:
    print("O número digitado pertence às extremidades de ", a, "e ", b)
else:
    print("O número digitado não pertence às extremidades")

# %%
"""
Spyder Stevie

This is a temporary script file.
"""

"""
Dados três números inteiros correspondentes, respectivamente ao dia, mês e ano 
do nascimento de uma pessoa e três outros números correspondentes, 
respectivamente ao dia, mês e ano corrente, determinar e imprimir a 
idade em anos completos.

"""
dd = int(input("Digite o dia de nascimento: "))
mm = int(input("Digite o mês de nascimento: "))
aa = int(input("Digite o ano de nascimento:"))
dd2 = int(input("Digite um dia qualquer: "))
mm2 = int(input("Digite um mês qualquer "))
aa2 = int(input("Digite um ano qualquer:"))

cont_aa = aa2 - aa

if mm>mm2 or (mm==mm2 and aa>aa2):
    cont_aa = cont_aa -1
    print("Você tem %i anos!" %cont_aa)

#Tá incompleto, preciso organizar melhor as datas ou colocar dentro de uma função.

# %%
"""


@author: Stevie Ferreira Amorim - 141032

1-) Elabore um programa em Python que calcule o que deve ser pago por um produto, considerando o preço normal de etiqueta e a escolha da condição de pagamento. O programa deverá pedir as seguintes entradas: o código do produto, o preço da etiqueta do produto e a condição de pagamento.

Utilize os códigos da tabela a seguir para a condição de pagamento escolhida e efetuar o cálculo adequado.
"""


cd_produto = int(input("Insira o código do produto: " ))
preco = int(input("Qual é o valor do produto? "
tipo_pagamento = str(input("Qual a forma de pagamento? "))
parcela = preco/2
juros= (preco*0.1)+preco
desconto = 0 
parcela_juros = juros/2

if tipo_pagamento == "A":
	print ("O valor do produto", cd_produto, ", é: ", preco, "O seu desconto será de 10%")
	desconto += preco*0.1
if tipo_pagamento == "B":
	print ("O valor do produto", cd_produto, ", é: ", preco, "O seu desconto será de 15%")
	desconto += preco*0.15
if tipo_pagamento == "C":
	print ("O valor do produto", cd_produto, ", é: ", preco, " Será feito em duas vezes sem juros, o valor em duas vezes será de : R$ ", parcela)
if tipo_pagamento == "D":
	print ("O valor do produto", cd_produto, ", é: ", preco, " Será feito em duas vezes com juros de 10%, o valor em duas vezes será de : R$ ", parcela_juros)

# %%
"""


@author: Stevie Ferreira Amorim - 141032

Escreva um programa em Python que receba duas notas, calcule e mostre a média ponderada destas, 
considerando peso 2 para a primeira nota e peso 3 para a segunda nota
"""

n1 = int(input("Digite a primeira nota: "))
peso1 = n1*2
n2 = int(input("Digite a segunda nota: "))
peso2 = n2*3
media = (peso1 +peso2)/2

print("A média com os pesos da nota é: ", media)

# %%
#Utilizando listas
lista = ['gabriel MEdina', 'Italo Ferreira', 'Larissa leal', 'rebeca Andrade', 'larissa leal', 'gabriel Medina', 'Rebeca andrade', 'Isaquias Queiroz', 'Rebeca Andrade']

def Medalhas(lista):
    novaLista = []
    totalComRepetidos = []
    total = []
    for x in lista:
        x = x.lower()
        novaLista.append(x)

    for x in novaLista:
        y = novaLista.count(x)
        totalComRepetidos.append([x, y])
    for x in totalComRepetidos:
        if x not in total:
            total.append(x)
    return(total)
    print(total)

# %%
n = int(input('digite o valor de n '))
numero = int(input('o primeiro numero '))
soma = 0
maiorN = numero
menorN = numero
for x in range(0, (n-1), 1):
    soma += numero
    
    if numero > maiorN:
        maiorN = numero
    if numero < menorN:
        menorN = numero
    numero = int(input('qual o proximo numero '))        

soma += numero
if numero > maiorN:
    maiorN = numero
if numero < menorN:
    menorN = numero
media = soma/n

print('a media aritmética é igual a ', media, ',o menor número é ', menorN, ' e o maior é ', maiorN)

# %%
"""
Created on Mon May 17 19:10:08 2021

@author: Stevie Amorim -  141032
"""
#1-)Faça um programa que leia o tempo de duração de um evento em uma fábrica expressa em segundos e mostre-o expresso em horas, minutos e segundos.

segundos = int(input("Digite quanto tempo em segundos: "))
segundos_rest = segundos % 86400
horas = segundos_rest // 3600
segundos_rest = segundos_rest % 3600
minutos = segundos_rest // 60
segundos_rest = segundos_rest % 60

print(horas,"horas,",minutos,"minutos e",segundos_rest,"segundos.")

# %%
"""
Spyder Editor

This is a temporary script file.
"""
#Stevie Ferreira Amorim - 141032
#Talles Lima Augusto - 141460

#1-)Faça um programa que calcule e mostre o maior número,
# o menor e a média aritmética de N números inteiros positivos digitados.'

n = int(input('digite o valor de n '))
a = int(input('o primeiro numero '))
y = 0
z = a
h = a
for x in range(0, (n-1), 1):
    y += a
    
    if a > z:
        z = a
    elif a < h:
        h = a
    a = int(input('qual o proximo numero '))        

y += a
    
if a > z:
    z = a
if a < h:
    h = a
media = y/n

print('a media aritmética é igual a ', media, ',o menor número é ', h, ' e o maior é ', z)

# %%
"""
Spyder Editor

This is a temporary script file.
"""
#Stevie Ferreira Amorim - 141032
#Talles Lima Augusto - 141460

#1-)Faça um programa que calcule e mostre o maior número,
# o menor e a média aritmética de N números inteiros positivos digitados.'

n = int(input('digite o valor de n '))
a = int(input('o primeiro numero '))
y = 0
z = a
h = a
for x in range(0, (n-1), 1):
    y += a
    
    if a > z:
        z = a
    elif a < h:
        h = a
    a = int(input('qual o proximo numero '))        

y += a
    
if a > z:
    z = a
if a < h:
    h = a
media = y/n

print('a media aritmética é igual a ', media, ',o menor número é ', h, ' e o maior é ', z)

# %%
"""
Created on Thu Jul 22 23:48:41 2021

@author: Stevie - 141032 - noturno

programa para organizar sobrenome.
"""

def abnt():
    nm_nome = str(input("Fale o nome "))
    
    if ' Da ' in nm_nome:
        acheDa = nm_nome.find(' Da ')
        antesDa = nm_nome[:acheDa]
        depoisDa = nm_nome[acheDa+3:]
        semDa = antesDa + depoisDa
    else:
        semDa = nm_nome
    
    if ' Dos ' in semDa:
        acheDos = semDa.find(' Dos ')
        antesDos = semDa[:acheDos]
        depoisDos = semDa[acheDos+4:]
        semDos = antesDos + depoisDos
    else:
        semDos = semDa

    
    if ' De ' in semDos:
        acheDe = semDos.find(' De ')
        antesDe = semDos[:acheDe]
        depoisDe = semDos[acheDe+3:]
        semDe = antesDe + depoisDe
    else:
        semDe = semDos
        
    if ' E ' in semDe:
        acheE = semDe.find(' E ')
        antesE = semDe[:acheE]
        depoisE = semDe[acheE+2:]
        semE = antesE + depoisE  
    else:
        semE = semDe

    
    acharUltimo = semE.rfind(" ")
    ultimo = semE[(acharUltimo + 1):]
    primeiro = semE[0]
    
    frase = ultimo + ', ' + primeiro
    
    nm_nome = semE[:acharUltimo]
    
    while ' ' in nm_nome:
        acharUltimo = nm_nome.find("   ")
        print(acharUltimo)
        frase = frase + ', ' + nm_nome[acharUltimo+1]
        nm_nome = nm_nome[acharUltimo+1:]
    
    print(frase)
